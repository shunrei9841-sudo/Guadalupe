# %% [markdown]
# <a href="https://colab.research.google.com/github/shunrei9841-sudo/Guadalupe/blob/main/Ejercicio%202%20corregido%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros del ejercicio 2
mu_C1 = 100000
sigma_C1 = 500
a = 800000
lambda_T = 1/5

# Parámetros de la simulación
n_muestra = 1000 # Tamaño de la muestra (inciso a)
n_bootstrap = 10000 # Número de re-muestreos

print(f"--- Ejercicio 2: Costo Total del Proyecto ---")

# --- Paso 1: Generar la Muestra para CT (Inciso a) ---
np.random.seed(42)

# Simular T y C2 (El scale para la exponencial es 1/lambda)
T_muestra = np.random.exponential(scale=1/lambda_T, size=n_muestra)
C2_muestra = a * T_muestra

# Simular C1 (Normal)
C1_muestra = np.random.normal(loc=mu_C1, scale=sigma_C1, size=n_muestra)

# Costo Total
CT_muestra = C1_muestra + C2_muestra

print(f"\na) Generada muestra de {n_muestra} para el Costo Total (CT).")


# --- Paso 2: b) Estimar la media y la desviación estándar para CT ---
media_CT_est = np.mean(CT_muestra)
std_CT_est = np.std(CT_muestra, ddof=1)
varianza_CT_est = std_CT_est**2 # Necesaria para el inciso c)

print("\nb) Estimaciones a partir de la muestra:")
print(f"  Media Muestral (Estimación de la Media de CT): {media_CT_est:,.2f}")
print(f"  Desviación Estándar Muestral (Est. de la Desv. Std.): {std_CT_est:,.2f}")


# --- Paso 3: c) Estimar Varianza y MSE de los estimadores usando Bootstrap ---
# Almacenar las estimaciones bootstrap
medias_bootstrap = np.empty(n_bootstrap)
varianzas_bootstrap = np.empty(n_bootstrap)

for i in range(n_bootstrap):
    # Generar una re-muestra con reemplazo del tamaño de la muestra original
    re_muestra = np.random.choice(CT_muestra, size=n_muestra, replace=True)

    # Calcular y almacenar las estadísticas de la re-muestra
    medias_bootstrap[i] = np.mean(re_muestra)
    varianzas_bootstrap[i] = np.var(re_muestra, ddof=1)


# Cálculo de la Varianza del Estimador (Bootstrap)
var_media_boot = np.var(medias_bootstrap)
var_varianza_boot = np.var(varianzas_bootstrap)

# Cálculo del Sesgo (Bias) del Estimador (Bootstrap)
# Sesgo = E[Estimador] - Parámetro_Estimado_en_b
bias_media_boot = np.mean(medias_bootstrap) - media_CT_est
bias_varianza_boot = np.mean(varianzas_bootstrap) - varianza_CT_est

# Cálculo del Error Cuadrático Medio (MSE) del Estimador (Bootstrap)
# MSE = Varianza + Sesgo^2
mse_media_boot = var_media_boot + bias_media_boot**2
mse_varianza_boot = var_varianza_boot + bias_varianza_boot**2

print("\nc) Estimación por Bootstrap de la Varianza y MSE del estimador:")
print("  | Estimador | Varianza (Bootstrap) | Sesgo (Bootstrap) | MSE (Bootstrap) |")
print("  |-----------|----------------------|-------------------|-----------------|")
print(f"  | Media     | {var_media_boot:,.2f}             | {bias_media_boot:,.2f}          | {mse_media_boot:,.2f}        |")
print(f"  | Varianza  | {var_varianza_boot:,.2f}             | {bias_varianza_boot:,.2f}          | {mse_varianza_boot:,.2f}        |")
# Out:
# --- Ejercicio 2: Costo Total del Proyecto ---
#
# a) Generada muestra de 1000 para el Costo Total (CT).
#
# b) Estimaciones a partir de la muestra:
#   Media Muestral (Estimación de la Media de CT): 3,990,073.24
#   Desviación Estándar Muestral (Est. de la Desv. Std.): 3,890,017.60
#
# c) Estimación por Bootstrap de la Varianza y MSE del estimador:
#   | Estimador | Varianza (Bootstrap) | Sesgo (Bootstrap) | MSE (Bootstrap) |
#   |-----------|----------------------|-------------------|-----------------|
#   | Media     | 14,800,814,078.00             | 258.66          | 14,800,880,984.62        |
#   | Varianza  | 1,671,905,137,453,786,562,822,144.00             | -9,333,890,945.96          | 1,671,992,258,973,977,620,250,624.00        |
