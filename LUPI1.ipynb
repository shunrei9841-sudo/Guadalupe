# %% [markdown]
# <a href="https://colab.research.google.com/github/shunrei9841-sudo/Guadalupe/blob/main/LUPI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 4.
print(x)
# Out:
# 4.0

# %%
# Variable of type String
newVariable = "12" + "2.3"
print(type(newVariable))
# Out:
# <class 'str'>

# %%
lupita = True
#pepi
print(lupita)
print(type(lupita))
# Out:
# True
# <class 'bool'>

# %%
from datetime import timedelta
luis = timedelta(
    days=9,
    seconds=27,
    microseconds=10,
    milliseconds=29000,
    minutes=5,
    hours=8,
    weeks=2
)
print(luis)
# Only days, seconds, and microseconds remain
# Out:
# 23 days, 8:05:56.000010

# %%
import datetime
import math
import statistics
import pandas
import numpy
import matplotlib.pyplot as plt
#as lo que hace es renombrar la libreria para usarlo en el codigo de manera mas corta
#matplotlib = plt

# %%
edad = 20
es_mayor_de_edad = edad >= 18
print(es_mayor_de_edad)  # Salida: True
# Comparación entre cadenas
nombre = "Juan"
es_juan = nombre == "Juan"
print(es_juan)
# Out:
# True
# True
